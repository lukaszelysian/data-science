# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stat
from scipy.stats import skew
from scipy.stats import kurtosis

# %%
data_1=pd.read_csv(r"C:\Users\luqsu\OneDrive\Desktop\tech crush\data sci\pizza_sales\order_details.csv")
data_1
# Out:
#        order_details_id  order_id       pizza_id  quantity
# 0                     1         1     hawaiian_m         1
# 1                     2         2  classic_dlx_m         1
# 2                     3         2  five_cheese_l         1
# 3                     4         2    ital_supr_l         1
# 4                     5         2     mexicana_m         1
# ...                 ...       ...            ...       ...
# 48615             48616     21348  ckn_alfredo_m         1
# 48616             48617     21348  four_cheese_l         1
# 48617             48618     21348   napolitana_s         1
# 48618             48619     21349     mexicana_l         1
# 48619             48620     21350      bbq_ckn_s         1
#
# [48620 rows x 4 columns]

# %%
data_2=pd.read_csv(r"C:\Users\luqsu\OneDrive\Desktop\tech crush\data sci\pizza_sales\orders.csv")

data_2
# Out:
#        order_id        date      time
# 0             1  2015-01-01  11:38:36
# 1             2  2015-01-01  11:57:40
# 2             3  2015-01-01  12:12:28
# 3             4  2015-01-01  12:16:31
# 4             5  2015-01-01  12:21:30
# ...         ...         ...       ...
# 21345     21346  2015-12-31  20:51:07
# 21346     21347  2015-12-31  21:14:37
# 21347     21348  2015-12-31  21:23:10
# 21348     21349  2015-12-31  22:09:54
# 21349     21350  2015-12-31  23:02:05
#
# [21350 rows x 3 columns]

# %%
data_3=pd.read_csv(r"C:\Users\luqsu\OneDrive\Desktop\tech crush\data sci\pizza_sales\pizza_typess.csv")
data_3
# Out:
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       cali_ckn                The California Chicken Pizza  Chicken
# 2    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 3      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 4     southw_ckn                 The Southwest Chicken Pizza  Chicken
# 5       thai_ckn                      The Thai Chicken Pizza  Chicken
# 6       big_meat                          The Big Meat Pizza  Classic
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8       hawaiian                          The Hawaiian Pizza  Classic
# 9    ital_cpcllo                 The Italian Capocollo Pizza  Classic
# 10    napolitana                        The Napolitana Pizza  Classic
# 11   pep_msh_pep  The Pepperoni, Mushroom, and Peppers Pizza  Classic
# ...

# %%
data_4=pd.read_csv(r"C:\Users\luqsu\OneDrive\Desktop\tech crush\data sci\pizza_sales\pizzas.csv")
data_4
# Out:
#          pizza_id pizza_type_id size  price
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      cali_ckn_s      cali_ckn    S  12.75
# 4      cali_ckn_m      cali_ckn    M  16.75
# ..            ...           ...  ...    ...
# 91  spinach_fet_m   spinach_fet    M  16.00
# 92  spinach_fet_l   spinach_fet    L  20.25
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
# [96 rows x 4 columns]

# %%
df=pd.concat([data_1,data_2,data_3,data_4],axis=1,ignore_index=False)
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_id  \
# 0                     1         1     hawaiian_m         1       1.0
# 1                     2         2  classic_dlx_m         1       2.0
# 2                     3         2  five_cheese_l         1       3.0
# 3                     4         2    ital_supr_l         1       4.0
# 4                     5         2     mexicana_m         1       5.0
# ...                 ...       ...            ...       ...       ...
# 48615             48616     21348  ckn_alfredo_m         1       NaN
# 48616             48617     21348  four_cheese_l         1       NaN
# 48617             48618     21348   napolitana_s         1       NaN
# 48618             48619     21349     mexicana_l         1       NaN
# 48619             48620     21350      bbq_ckn_s         1       NaN
#
#              date      time pizza_type_id                          name  \
# ...

# %%
df.columns.values[2]="pizza_id_one"
df.columns.values[1]="order_id_one"
df.columns.values[7]="pizza_id_type_one"

#df.drop(columns="order_id")

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48615    False
# 48616    False
# 48617    False
# 48618    False
# 48619    False
# Length: 48620, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# order_details_id         0
# order_id_one             0
# pizza_id_one             0
# quantity                 0
# order_id             27270
# date                 27270
# time                 27270
# pizza_id_type_one    48588
# name                 48588
# category             48588
# ingredients          48588
# pizza_id             48524
# pizza_type_id        48524
# size                 48524
# price                48524
# dtype: int64

# %%
#df.fillna("UNKNOWN")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id_one       48620 non-null  int64
#  2   pizza_id_one       48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_id           21350 non-null  float64
#  5   date               21350 non-null  object
#  6   time               21350 non-null  object
#  7   pizza_id_type_one  32 non-null     object
#  8   name               32 non-null     object
#  9   category           32 non-null     object
#  10  ingredients        32 non-null     object
#  11  pizza_id           96 non-null     object
#  12  pizza_type_id      96 non-null     object
#  13  size               96 non-null     object
#  14  price              96 non-null     float64
# dtypes: float64(2), int64(3), object(10)
# ...

# %%
#df["price"]=df["price"].replace({"UNKNOWN": 0})
#df["date"]=df["date"].replace({"UNKNOWN": 0})
#df["time"]=df["time"].replace({"UNKNOWN": 0})

# %%
df["price"]=pd.to_numeric(df["price"],errors="coerce")

# %%
df["quantity"]=pd.to_numeric(df["quantity"],errors="coerce")
#df.drop(columns=["pizza_type_id"],["pizza_id"],inplace=True)
df["order_id_one"]=pd.to_numeric(df["order_id_one"],errors="coerce")

# %%
df["Revenue"]=df["quantity"]*df["price"]

# %%
df["time"]=pd.to_datetime(df["time"])
# Out:
# C:\Users\luqsu\AppData\Local\Temp\ipykernel_3780\3514199418.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["time"]=pd.to_datetime(df["time"])

# %%
df["Hour"]=df["time"].dt.hour
df["Day"]=df["time"].dt.day
df["Month"]=df["time"].dt.month

# %% [markdown]
# Total Revenue

# %%
Total_revenue=df["Revenue"].sum()
print("Total Revenue:", Total_revenue)
# Out:
# Total Revenue: 1590.8

# %% [markdown]
# Total quantity

# %%
Total_quantity=df["quantity"].sum()

# %%
print("Total Quantity:", Total_quantity)
# Out:
# Total Quantity: 49574

# %% [markdown]
# Total orders

# %%
Total_orders=df["order_id_one"].sum()

# %%
print("Total Orders:", Total_orders)
# Out:
# Total Orders: 520305946

# %% [markdown]
# Total pizza types

# %%
Total_pizza_types=df["pizza_id_type_one"].value_counts()

# %%
print("Total pizza types:", Total_pizza_types.value_counts().sum())
# Out:
# Total pizza types: 32

# %% [markdown]
# Average price of pizzas

# %%
print("The Average price of pizzas:", df["price"].mean().round(3))
# Out:
# The Average price of pizzas: 16.441

# %%
df.tail()
# Out:
#        order_details_id  order_id_one   pizza_id_one  quantity  order_id date  \
# 48615             48616         21348  ckn_alfredo_m         1       NaN  NaN
# 48616             48617         21348  four_cheese_l         1       NaN  NaN
# 48617             48618         21348   napolitana_s         1       NaN  NaN
# 48618             48619         21349     mexicana_l         1       NaN  NaN
# 48619             48620         21350      bbq_ckn_s         1       NaN  NaN
#
#       time pizza_id_type_one name category ingredients pizza_id pizza_type_id  \
# 48615  NaT               NaN  NaN      NaN         NaN      NaN           NaN
# 48616  NaT               NaN  NaN      NaN         NaN      NaN           NaN
# 48617  NaT               NaN  NaN      NaN         NaN      NaN           NaN
# 48618  NaT               NaN  NaN      NaN         NaN      NaN           NaN
# 48619  NaT               NaN  NaN      NaN         NaN      NaN           NaN
#
# ...

# %% [markdown]
# Peak Hours of Sales

# %%
Peak_hour_of_sales_by_Revenue=df.groupby("Hour")["Revenue"].sum().sort_values(ascending=False)

# %%
print("The peak hour of sales by revenue generated:", Peak_hour_of_sales_by_Revenue.head(1))
# Out:
# The peak hour of sales by revenue generated: Hour
# 12.0    280.7
# Name: Revenue, dtype: float64

# %% [markdown]
# Total sales made on each day of the week

# %%
#df["Day_name"]=df["Day"].dt.day_name()
#df["Month_name"]=df["Month"].dt.month_name()

# %%
daily_sales=df.groupby("Day_name")["Revenue"].sum()

# %%
daily_sales

# %%
print("The day of the week with the most sales:", daily_sales)

# %% [markdown]
# Top 5 best selling pizzas

# %%
v=df.groupby("pizza_id_type_one")["quantity"].sum().sort_values(ascending=False)

# %%
print("The top 5 best selling pizzas are:",v.head(5))

# %% [markdown]
# Monthly sales

# %%
df["Month"]=df["time"].dt.month_name()
#df["Month_id"]=df["date"].dt.month
#monthly_sales=df.groupby(["Month_id","Month"])["Revenue"].sum().reset_index()
monthly_sales=monthly_sales.sort_values("Month_id")
print("the month with the highest sales :",monthly_sales.max())
# Out:
# the month with the highest sales : Month_id        12.0
# Month       February
# Revenue       1590.8
# dtype: object

# %% [markdown]
# Trend

# %%
plt.plot(monthly_sales["Month_id"],monthly_sales["Month"],color="green",marker="1")
plt.title("Trend of Monthly sales")
plt.xlabel("Month_id")
plt.ylabel("Month")
plt.show()

# %% [markdown]
# the trend showed that sales were only recorded in february.

# %% [markdown]
# pizza types that are not doing well on the menu

# %%
df["pizza_id_type_one"].value_counts()
# Out:
# pizza_id_type_one
# bbq_ckn         1
# cali_ckn        1
# spinach_fet     1
# spin_pesto      1
# mexicana        1
# mediterraneo    1
# ital_veggie     1
# green_garden    1
# four_cheese     1
# five_cheese     1
# spinach_supr    1
# spicy_ital      1
# soppressata     1
# sicilian        1
# prsc_argla      1
# peppr_salami    1
# ital_supr       1
# calabrese       1
# brie_carre      1
# the_greek       1
# pepperoni       1
# pep_msh_pep     1
# napolitana      1
# ital_cpcllo     1
# hawaiian        1
# classic_dlx     1
# big_meat        1
# thai_ckn        1
# southw_ckn      1
# ckn_pesto       1
# ckn_alfredo     1
# veggie_veg      1
# Name: count, dtype: int64

# %% [markdown]
# the data shows that all the pizza types have uniform performance
